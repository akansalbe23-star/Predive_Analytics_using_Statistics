# %% [markdown]
# <a href="https://colab.research.google.com/github/akansalbe23-star/Predive_Analytics_using_Statistics/blob/main/Predictive_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Assignment 1

# %%
### Importing The Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Reading the File
df = pd.read_csv('/content/data.csv',encoding='latin1')
df.head()
# Out:
# /tmp/ipython-input-636630543.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data.csv',encoding='latin1')
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
# ...

# %%
### Taking Our Required Column
x=df['no2']
x.shape
# Out:
# (435742,)

# %%
### Checking for NULL values
x.isnull().sum()
# Out:
# np.int64(16233)

# %%
### Droping the NULL values
x.dropna(inplace=True)
x.shape
# Out:
# (419509,)

# %%
### Defining My Roll Number
R=102303808

# %%
### Computing the Transformation cofficients
ar = 0.05*(R % 7)
br = 0.3 *((R % 5) + 1)
print(f'ar coffiecient = {ar}')
print(f'br coffiecient = {br}')
# Out:
# ar coffiecient = 0.25
# br coffiecient = 1.2

# %%
### The Transformation of X into Z
z = x + ar * np.sin(br * x)
z.shape
# Out:
# (419509,)

# %%
### checking the z head
z.head()
# Out:
# 0    17.624052
# 1     7.213650
# 2    28.587488
# 3    14.466135
# 4     7.603030
# Name: no2, dtype: float64

# %%
### The Equation given in the question is the eqation of the Gaussian Dist
### The form p(z)=1/sqrt(2*pi*var) * e^((z-u)^2/(2*var))

# %%
### Calculating the Values of lam,u,c
u = np.mean(z)
var = np.var(z,ddof=0)
lam = 1/(2*var)
c=1/np.sqrt(2*np.pi*var)

# %%
### Printing the Values
print(f'u value : {u}')
print(f'lam value : {lam}')
print(f'c value : {c}')
# Out:
# u value : 25.804148934144695
# lam value : 0.001459639502085521
# c value : 0.02155499208485605

# %%
### Rounding the values
u=round(u,6)
lam=round(lam,6)
c=round(c,6)

# %%
### Printing The Rounded Values
print(f'u value : {u}')
print(f'lam value : {lam}')
print(f'c value : {c}')
# Out:
# u value : 25.804149
# lam value : 0.00146
# c value : 0.021555
